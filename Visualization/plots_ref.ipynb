# %% [markdown]
# ## Import libraries

# %%
import sys
sys.path.append('../edaf')

# %%
# from edaf.core.uplink.preprocess import preprocess_ul
# from edaf.core.uplink.analyze_packet import ULPacketAnalyzer
# from edaf.core.uplink.analyze_channel import ULChannelAnalyzer
# from edaf.core.uplink.analyze_scheduling import ULSchedulingAnalyzer

from plot_helpers import *
from data_helpers import *
import seaborn as sns
from decomp import *
from sortedcontainers import SortedList, SortedDict
from loguru import logger
import os, sys, gzip, json
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from IPython.display import JSON

from pathlib import Path
import ijson

# %load_ext autoreload
# %autoreload 2

sns.set_theme(style='darkgrid')  # Options include 'darkgrid', 'whitegrid', 'dark', 'white', and 'ticks'
sns.set()

# %%
# Remove default handler
logger.remove()
# Add a new handler with level WARNING
logger.add(sys.stdout, level="ERROR")
# Out:
# 2

# %% [markdown]
# ## Intialize paths

# %%
MEAS_DIR = '../S1-meas/'
MEAS_LABEL = 's49'
DB_FILE = MEAS_DIR+MEAS_LABEL+'/'+'res_db.sql'
PLOTS_DIR = './plots/'+MEAS_LABEL+'/'
DATA_DIR = './data/'+MEAS_LABEL+'/'

# %% [markdown]
# ## Analyzers

# %%
IMPORT_FROM_JSON=True

# %%
MEAS_DIR = '../S1-meas/' ### change the paths here
MEAS_LABEL = 's49/jsons/'
DB_FILE = MEAS_DIR+MEAS_LABEL+'/'+'res_db.sql'
PLOTS_DIR = './plots/'+MEAS_LABEL+'/'
DATA_DIR = './data/'+MEAS_LABEL+'/'

IMPORT_FROM_JSON = True

if IMPORT_FROM_JSON==False:
    # packet analyzer
    analyzer = ULPacketAnalyzer(DB_FILE)
    uids_arr = range(analyzer.first_ueipid, analyzer.last_ueipid+1)
    packets = analyzer.figure_packettx_from_ueipids(uids_arr)
    packets_rnti_set = set([item['rlc.attempts'][0]['rnti'] for item in packets if item['rlc.attempts'][0]['rnti']!=None])
    print(f'RNTIs in packets: {list(packets_rnti_set)}')
    # sched analyzer
    sched_analyzer = ULSchedulingAnalyzer(
        total_prbs_num = 106, 
        symbols_per_slot = 14, 
        slots_per_frame = 20, 
        slots_duration_ms = 0.5, 
        scheduling_map_num_integers = 4,
        max_num_frames=100,
        db_addr = DB_FILE
    )
    
    begin_ts = sched_analyzer.first_ts
    end_ts = sched_analyzer.last_ts
    sched_arr = sched_analyzer.find_resource_schedules_from_ts(begin_ts, end_ts)
    sched_sorted_dict = SortedDict({sched['decision_ts']: sched for sched in sched_arr})
    bsrupd_arr = sched_analyzer.find_bsr_upd_from_ts(begin_ts, end_ts)
    sr_tx_arr = sched_analyzer.find_sr_tx_from_ts(begin_ts, end_ts)
    bsr_tx_arr = sched_analyzer.find_bsr_tx_from_ts(begin_ts, end_ts)
    sr_bsr_tx_sorted_list = SortedList([sr_tx['timestamp'] for sr_tx in sr_tx_arr]+[bsr_tx['timestamp'] for bsr_tx in bsr_tx_arr])
    
    chan_analyzer = ULChannelAnalyzer(DB_FILE)
    begin_ts = chan_analyzer.first_ts
    end_ts = chan_analyzer.last_ts
    WINDOW_LEN_SECONDS = 2
    mcs_arr_all = chan_analyzer.find_mcs_from_ts(begin_ts,end_ts)
    tb_arr = chan_analyzer.find_mac_attempts_from_ts(begin_ts,end_ts)
    set_rnti = set([item['rnti'] for item in mcs_arr_all])
    # filter entries with rnti list(packets_rnti_set)[0] 
    if list(packets_rnti_set)[0]!=None:
        mcs_arr = [mcs for mcs in mcs_arr_all if mcs['rnti']==list(packets_rnti_set)[0]]
    mcs_sorted_dict = SortedDict({mcs['timestamp']: mcs for mcs in mcs_arr})

    #print(f'RNTIs in channel: {list(set_rnti)}')
else:
    packets = read_json(DATA_DIR+'packets.json')
    sr_tx_arr = read_json(DATA_DIR+'sr_tx.json')
    bsr_tx_arr = read_json(DATA_DIR+'bsr_tx.json')
    bsrupd_arr = read_json(DATA_DIR+'bsr_upd.json')
    bsrupd_sorted_dict = SortedDict({bsrupd['timestamp']: bsrupd for bsrupd in bsrupd_arr})
    sr_bsr_tx_sorted_list = SortedList([sr_tx['timestamp'] for sr_tx in sr_tx_arr]+[bsr_tx['timestamp'] for bsr_tx in bsr_tx_arr])
    sched_arr = read_json(DATA_DIR+'sched.json')
    sched_sorted_dict = SortedDict({sched['decision_ts']: sched for sched in sched_arr})
    packets_rnti_set = set([item['rlc.attempts'][0]['rnti'] for item in packets if item['rlc.attempts'][0]['rnti']!=None])
    print(f'RNTIs in packets: {list(packets_rnti_set)}')
    mcs_arr_all = read_json(DATA_DIR+'mcs.json')
    tb_arr = read_json(DATA_DIR+'tb.json')
    set_rnti = set([item['rnti'] for item in mcs_arr_all])
    #filter entries with rnti list(packets_rnti_set)[0] 
    if list(packets_rnti_set)[0]!=None:
        mcs_arr = [mcs for mcs in mcs_arr_all if mcs['rnti']==list(packets_rnti_set)[0]]
    else:
        mcs_arr = mcs_arr_all
    mcs_sorted_dict = SortedDict({mcs['timestamp']: mcs for mcs in mcs_arr})

    #print(f'RNTIs in channel: {list(set_rnti)}')
# Out:
# RNTIs in packets: ['5fcf']

# %% [markdown]
# ## Calculate delays

# %%
# send_ts = analyzer.nlmt_df['timestamps.client.send.wall'].to_numpy()
# send_ts = (send_ts)/1e6
# receive_ts = analyzer.nlmt_df['timestamps.server.receive.wall'].to_numpy()
# receive_ts = (receive_ts)/1e6
# idt = (send_ts[1:-1]-send_ts[0:-2])
# e2e_delays = receive_ts-send_ts

idt = np.array(list({packets[ind]['id']: packets[ind]['ip.in_t']-packets[ind-1]['ip.in_t'] for ind in range(1, len(packets)) if packets[ind]['ip.in_t']!=None and  packets[ind-1]['ip.in_t']!=None}.values()))
frame_alignment_delays = np.array(list({packet['id']: get_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5) for packet in packets if get_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5)!=None}.values()))
scheduling_delays = np.array(list({packet['id']: get_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) for packet in packets if get_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5)!=None}.values()))
ran_delays = np.array(list({packet['id']: get_ran_delay(packet) for packet in packets if get_ran_delay(packet)!=None}.values()))
ran_delays_wo_frame_alignment_delay = np.array(list({packet['id']: get_ran_delay_wo_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5) for packet in packets if get_ran_delay_wo_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5)!=None}.values()))
ran_delays_wo_scheduling_delay = np.array(list({packet['id']: get_ran_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) for packet in packets if get_ran_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5)!=None}.values()))
queueing_delays = np.array(list({packet['id']: get_queueing_delay(packet) for packet in packets if get_queueing_delay(packet)!=None}.values()))
queueing_delays_wo_scheduling_delay = np.array(list({packet['id']: get_queueing_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) for packet in packets if get_queueing_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5)!=None}.values()))
segmentation_delay = np.array(list({packet['id']: get_segmentation_delay(packet) for packet in packets if get_segmentation_delay(packet)!=None}.values()))
segmentation_delays_wo_scheduling_delay = np.array(list({packet['id']: get_segmentation_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) for packet in packets if get_segmentation_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5)!=None}.values()))
segments = np.array(list({packet['id']: get_segments(packet) for packet in packets if get_segments(packet)!=None}.values()))
retx_delays = np.array(list({packet['id']: get_retx_delay(packet) for packet in packets if get_retx_delay(packet)!=None}.values()))
mcss = np.array(list({packet['id']: get_mcs(packet, mcs_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) for packet in packets if get_mcs(packet, mcs_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5)!=None}.values()))
tbss = np.array(
    list(
        {
            packet["id"]: get_tbs(packet, sched_sorted_dict, slots_duration_ms=0.5)
            for packet in packets
            if get_tbs(
                packet, mcs_sorted_dict, slots_duration_ms=0.5
            )
            != None
        }.values()
    )
)
# Out:
# 2024-11-11 23:14:39.331 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.333 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.334 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.334 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.378 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.380 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.388 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.390 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.399 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.400 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.423 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.424 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.425 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.426 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.433 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.435 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.467 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.468 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.633 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.634 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.662 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.663 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.664 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.665 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.794 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.795 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.818 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.820 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.821 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.825 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.871 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.872 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.920 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.921 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.932 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.932 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.934 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:39.935 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.031 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.032 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.033 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.035 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.043 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.044 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.047 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.048 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.280 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.281 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.290 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.290 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.291 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.294 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.396 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.398 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.481 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.482 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.492 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.493 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.494 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.495 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.578 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.580 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.747 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.748 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.749 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.750 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.751 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.752 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.839 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.841 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.854 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.855 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.867 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.870 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.884 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.885 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.970 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.971 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.972 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:40.973 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.063 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.064 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.237 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.238 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.328 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.330 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.407 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.409 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.410 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.411 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.421 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.421 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.422 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.423 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.485 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.486 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.550 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.552 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.553 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.554 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.610 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.611 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.622 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.623 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.638 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.640 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.679 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.681 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.682 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.683 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.691 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.693 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.738 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.740 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.970 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:41.971 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.005 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.006 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.007 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.010 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.183 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.184 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.203 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.204 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.205 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.206 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.255 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.256 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.316 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.317 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.326 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.327 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.328 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.330 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.455 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.457 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.458 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.460 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.468 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.469 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.473 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.473 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.766 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.768 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.778 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.779 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.781 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.783 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.901 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:42.902 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.029 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.030 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.041 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.043 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.045 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.047 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.175 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.177 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.400 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.402 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.403 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.404 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.405 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.406 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.527 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.528 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.546 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.548 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.560 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.561 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.584 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.592 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.756 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.758 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.760 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.762 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.868 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.869 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.979 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:43.981 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.060 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.061 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.136 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.137 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.138 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.139 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.151 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.152 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.153 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.153 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.219 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present
# 2024-11-11 23:14:44.220 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present

# %% [markdown]
# ## Plotting

# %%
# Ensure the PLOTS_DIR exists
if not os.path.exists(PLOTS_DIR):
    os.makedirs(PLOTS_DIR)
    
# skip first and last packets
SKIP_FIRST = 1000
SKIP_LAST = 100

# fig, ax  = plot_ccdf(e2e_delays[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
# plt.savefig(f"{PLOTS_DIR}e2e_delays_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
# plt.show()

fig, ax  = plot_ccdf(idt[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
plt.savefig(f"{PLOTS_DIR}idt_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax  = plot_ccdf(ran_delays[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
plt.savefig(f"{PLOTS_DIR}ran_delays_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax  = plot_ccdf(scheduling_delays[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
plt.savefig(f"{PLOTS_DIR}scheduling_delays_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax  = plot_ccdf(frame_alignment_delays[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
plt.savefig(f"{PLOTS_DIR}frame_alignment_delays_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax  = plot_ccdf(ran_delays_wo_scheduling_delay[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
plt.savefig(f"{PLOTS_DIR}ran_delays_wo_frame_alignment_delay_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax  = plot_ccdf(queueing_delays_wo_scheduling_delay[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
plt.savefig(f"{PLOTS_DIR}queueing_delays_wo_scheduling_delay_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax  = plot_ccdf(segmentation_delays_wo_scheduling_delay[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5))
plt.savefig(f"{PLOTS_DIR}segmentation_delays_wo_scheduling_delay_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax  = plot_ccdf(retx_delays[SKIP_FIRST:-SKIP_LAST], '_', figsize=(8, 5), x_lim=20)
plt.savefig(f"{PLOTS_DIR}retx_delays_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# plotting time series for frame alignment delay and scheduling delay
index_range = slice(5000, 6000)
SKIP_FIRST = 1000
SKIP_LAST = 100

# Create a figure and axes
fig, ax = plt.subplots(figsize=(12,5))

# Plotting each data set with different markers
ax.plot(frame_alignment_delays[index_range], marker='*', label='Frame alignment Delay')
ax.plot(scheduling_delays[index_range], marker='*', label='Scheduling delay')
ax.plot(ran_delays[index_range], marker='*', label='RAN delay')

# Adding labels and title
ax.set_xlabel('Index')
ax.set_ylabel('Delay [ms]')

# Adding grid
ax.grid(True)

# Adding legend
ax.legend()

# Save the plot
plt.savefig(f"{PLOTS_DIR}ran_delay_timeseries.png", dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

## ran delay without frame alignment delay and scheduling
# Create a figure and axes
fig, ax = plt.subplots(figsize=(12,5))

# Plotting each data set with different markers
ax.plot(ran_delays[index_range]-frame_alignment_delays[index_range], marker='o', label='RAN Delay w/o frame-alignment delay')
ax.plot(ran_delays[index_range]-scheduling_delays[index_range], marker='o', label='RAN Delay w/o scheduling delay')

# Adding labels and title
ax.set_xlabel('Index')
ax.set_ylabel('Delay [ms]')

# Adding grid
ax.grid(True)

# Adding legend
ax.legend()

# Save the plot
plt.savefig(f"{PLOTS_DIR}ran_delay_wo_scheduling_timeseries.png", dpi=300, bbox_inches='tight')

# %%
# index_range = range(5002, 5005)

# fig, ax = plt.subplots()

# uids_arr = index_range

# begin_ts,end_ts = plot_packet_tree_from_ueipids(uids_arr, analyzer.ue_ip_packets_df, analyzer.ue_iprlc_rel_df, analyzer.ue_rlc_segments_df, analyzer.ue_mac_attempts_df, analyzer.gnb_ip_packets_df, analyzer.gnb_iprlc_rel_df, analyzer.gnb_rlc_segments_df, analyzer.gnb_mac_attempts_df, ax, False)


# # Now plot Rerouce blocks on top
# plot_resourcegrid(begin_ts, end_ts, sched_analyzer.gnb_sched_maps_df, ax)

# plot_sched_tree(begin_ts, end_ts, sched_analyzer.ue_srtxs_df, sched_analyzer.ue_bsrupds_df, sched_analyzer.ue_bsrtxs_df, sched_analyzer.ue_uldcis_df, sched_analyzer.gnb_sched_reports_df, ax)

# # Set title, labels, and grid
# ax.set_xlabel('Time [ms]')  # Corrected: ax.set_xlabel()
# ax.set_ylabel('Scheduling Process')  # Corrected: ax.set_ylabel()
# ax.set_ylim([0,6])
# ax.set_xlim([0,(end_ts - begin_ts)*1000])
# ax.xaxis.grid(True)
# fig.set_figheight(5)
# fig.set_figwidth(9)
# fig.savefig(f"{PLOTS_DIR}res1.png")

# fig, ax = plt.subplots()

# begin_ts,end_ts = plot_packet_tree_from_ueipids(uids_arr, sched_analyzer.ue_ip_packets_df, sched_analyzer.ue_iprlc_rel_df, sched_analyzer.ue_rlc_segments_df, sched_analyzer.ue_mac_attempts_df, sched_analyzer.gnb_ip_packets_df, sched_analyzer.gnb_iprlc_rel_df, sched_analyzer.gnb_rlc_segments_df, sched_analyzer.gnb_mac_attempts_df, ax, True)

# plot_resourcegrid(begin_ts, end_ts, sched_analyzer.gnb_sched_maps_df, ax)

# # Set title, labels, and grid
# ax.set_xlabel('Time [ms]')  # Corrected: ax.set_xlabel()
# ax.set_ylabel('Packet Transmission Process')  # Corrected: ax.set_ylabel()
# ax.set_ylim([0,6])
# ax.set_xlim([0,(end_ts - begin_ts)*1000])
# ax.xaxis.grid(True)
# fig.set_figheight(5)
# fig.set_figwidth(9)
# fig.savefig(f"{PLOTS_DIR}res2.png")

# %% [markdown]
# # Code for multiple plots

# %% [markdown]
# ## Intialize paths

# %%
### combine plots
MEAS_DIR = '../S1-meas/'
MEAS_LABELS = ["s49/jsons/", "s40/jsons/", "s39/jsons/"]  # , 's57']
LABELS = ["s49", "s40", "s39"]#, 'Conf2']
DB_FILES = [ MEAS_DIR+MEAS_LABEL+'/'+'res_db.sql' for MEAS_LABEL in MEAS_LABELS]  # Add more DB files as needed

# %%
IMPORT_FROM_JSON=True

# %% [markdown]
# ## load multiple DB files and extract delays

# %%
# Initialize lists or dictionaries to store results from each file
packets_list = []
sched_sorted_dicts = []
bsrupd_sorted_dicts = []
sr_bsr_tx_sorted_lists = []
mcs_data = []
mcs_dicts = []
tb_data = []
delays_data = []  # New list to store delays for each file

# Loop through each label and perform the analysis
for MEAS_LABEL in MEAS_LABELS:
    if IMPORT_FROM_JSON == False:
        FILE_PATH = MEAS_DIR + MEAS_LABEL + '/' + 'res_db.sql'
        print(f'reading trace: {FILE_PATH}')
        
        # Packet analyzer
        analyzer = ULPacketAnalyzer(FILE_PATH)
        uids_arr = range(analyzer.first_ueipid, analyzer.last_ueipid + 1)
        packets = analyzer.figure_packettx_from_ueipids(uids_arr)
        packets_rnti_set = set([item['rlc.attempts'][0]['rnti'] for item in packets if item['rlc.attempts'][0]['rnti']!=None])
        print(f'RNTIs in packets: {list(packets_rnti_set)}')
        packets_list.append(packets)
        
        # Scheduling analyzer
        sched_analyzer = ULSchedulingAnalyzer(
            total_prbs_num=106,
            symbols_per_slot=14,
            slots_per_frame=20,
            slots_duration_ms=0.5,
            scheduling_map_num_integers=4,
            max_num_frames=100,
            db_addr=FILE_PATH
        )
        
        begin_ts = sched_analyzer.first_ts
        end_ts = sched_analyzer.last_ts
        sched_arr = sched_analyzer.find_resource_schedules_from_ts(begin_ts, end_ts)
        sched_sorted_dict = SortedDict({sched['decision_ts']: sched for sched in sched_arr})
        sched_sorted_dicts.append(sched_sorted_dict)
        
        bsrupd_arr = sched_analyzer.find_bsr_upd_from_ts(begin_ts, end_ts)
        bsrupd_sorted_dict = SortedDict({bsrupd['timestamp']: bsrupd for bsrupd in bsrupd_arr})
        bsrupd_sorted_dicts.append(bsrupd_sorted_dict)
        sr_tx_arr = sched_analyzer.find_sr_tx_from_ts(begin_ts, end_ts)
        bsr_tx_arr = sched_analyzer.find_bsr_tx_from_ts(begin_ts, end_ts)
        sr_bsr_tx_sorted_list = SortedList([sr_tx['timestamp'] for sr_tx in sr_tx_arr] + [bsr_tx['timestamp'] for bsr_tx in bsr_tx_arr])
        sr_bsr_tx_sorted_lists.append(sr_bsr_tx_sorted_list)

        # Channel analyzer
        chan_analyzer = ULChannelAnalyzer(FILE_PATH)
        begin_ts = chan_analyzer.first_ts
        end_ts = chan_analyzer.last_ts
        WINDOW_LEN_SECONDS = 2
        mcs_arr_all = chan_analyzer.find_mcs_from_ts(begin_ts, end_ts)
        set_rnti = set([item['rnti'] for item in mcs_arr_all])
        #print(f'RNTIs in channel: {list(set_rnti)}')
        # filter entries with rnti list(packets_rnti_set)[0] 
        if list(packets_rnti_set)[0]!=None:
            mcs_arr = [mcs for mcs in mcs_arr_all if mcs['rnti']==list(packets_rnti_set)[0]]    
        else:
            mcs_arr = mcs_arr_all
        mcs_dict = SortedDict({mcs['timestamp']: mcs for mcs in mcs_arr})
        mcs_dicts.append(mcs_dict)
        tb_arr = chan_analyzer.find_mac_attempts_from_ts(begin_ts, end_ts)
        mcs_data.append(mcs_arr)
        tb_data.append(tb_arr)
    else:
        DATA_DIR = './data/' + MEAS_LABEL + '/'
        print(f'reading from json in {DATA_DIR}')
        packets = read_json(DATA_DIR+'packets.json')
        packets_list.append(packets)
        packets_rnti_set = set([item['rlc.attempts'][0]['rnti'] for item in packets if item['rlc.attempts'][0]['rnti']!=None])
        print(f'RNTIs in packets: {list(packets_rnti_set)}')
                        
        sr_tx_arr = read_json(DATA_DIR+'sr_tx.json')
        bsr_tx_arr = read_json(DATA_DIR+'bsr_tx.json')
        bsrupd_arr = read_json(DATA_DIR+'bsr_upd.json')
        bsrupd_sorted_dict = SortedDict({bsrupd['timestamp']: bsrupd for bsrupd in bsrupd_arr})
        bsrupd_sorted_dicts.append(bsrupd_sorted_dict)

        bsrupd_sorted_dict = SortedDict({bsrupd['timestamp']: bsrupd for bsrupd in bsrupd_arr})
        sr_bsr_tx_sorted_list = SortedList([sr_tx['timestamp'] for sr_tx in sr_tx_arr]+[bsr_tx['timestamp'] for bsr_tx in bsr_tx_arr])
        sr_bsr_tx_sorted_lists.append(sr_bsr_tx_sorted_list)

        sched_arr = read_json(DATA_DIR+'sched.json')
        sched_sorted_dict = SortedDict({sched['decision_ts']: sched for sched in sched_arr})
        sched_sorted_dicts.append(sched_sorted_dict)
        mcs_arr_all = read_json(DATA_DIR+'mcs.json')
        set_rnti = set([item['rnti'] for item in mcs_arr_all])
        #print(f'RNTIs in channel: {list(set_rnti)}')
        if list(packets_rnti_set)[0]!=None:
            mcs_arr = [mcs for mcs in mcs_arr_all if mcs['rnti']==list(packets_rnti_set)[0]]    
        else:
            mcs_arr = mcs_arr_all
        tb_arr = read_json(DATA_DIR+'tb.json')
        mcs_data.append(mcs_arr)
        mcs_dict = SortedDict({mcs['timestamp']: mcs for mcs in mcs_arr})
        mcs_dicts.append(mcs_dict)
        tb_data.append(tb_arr)
    
    # Delays Calculation
    # send_ts = analyzer.nlmt_df['timestamps.client.send.wall'].to_numpy() / 1e6
    # receive_ts = analyzer.nlmt_df['timestamps.server.receive.wall'].to_numpy() / 1e6
    # idt = send_ts[1:-1] - send_ts[0:-2]
    # e2e_delays = receive_ts - send_ts
    
    # Frame alignment delays
    frame_alignment_delays = np.array(list({packet['id']: get_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5) 
                                            for packet in packets 
                                            if get_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5) is not None}.values()))
    
    # Scheduling delays
    scheduling_delays = np.array(list({packet['id']: get_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) 
                                       for packet in packets 
                                       if get_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) is not None}.values()))
    
    # RAN delays
    ran_delays = np.array(list({packet['id']: get_ran_delay(packet) 
                                for packet in packets 
                                if get_ran_delay(packet) is not None}.values()))
    
    # RAN delays without frame alignment
    ran_delays_wo_frame_alignment_delay = np.array(list({packet['id']: get_ran_delay_wo_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5) 
                                                         for packet in packets 
                                                         if get_ran_delay_wo_frame_alignment_delay(packet, sr_bsr_tx_sorted_list, slots_per_frame=20, slots_duration_ms=0.5) is not None}.values()))
    
    # RAN delays without scheduling delay
    ran_delays_wo_scheduling_delay = np.array(list({packet['id']: get_ran_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) 
                                                    for packet in packets 
                                                    if get_ran_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) is not None}.values()))
    
    # Queueing delays
    queueing_delays = np.array(list({packet['id']: get_queueing_delay(packet) 
                                     for packet in packets 
                                     if get_queueing_delay(packet) is not None}.values()))

    # Queueing delays without scheduling
    queueing_delays_wo_scheduling_delay = np.array(list({packet['id']: get_queueing_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) 
                                     for packet in packets 
                                     if get_queueing_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) is not None}.values()))
    
    # Retransmission delays
    retx_delays = np.array(list({packet['id']: get_retx_delay(packet) 
                                 for packet in packets 
                                 if get_retx_delay(packet) is not None}.values()))
    
    # Segmentation delays
    segmentation_delays = np.array(list({packet['id']: get_segmentation_delay(packet) 
                                 for packet in packets 
                                 if get_segmentation_delay(packet) is not None}.values()))

    # segmentation delays without scheduling delay
    segmentation_delays_wo_scheduling_delay = np.array(list({packet['id']: get_segmentation_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) 
                                 for packet in packets 
                                 if get_segmentation_delay_wo_scheduling_delay(packet, sched_sorted_dict, slots_per_frame=20, slots_duration_ms=0.5) is not None}.values()))    

    # segments
    segments = np.array(list({packet['id']: get_segments(packet) for packet in packets if get_segments(packet) is not None}.values()))
    

    # mcs 
    mcs = np.array(list({packet['id']: get_mcs(packet, mcs_dict) for packet in packets if get_mcs(packet, mcs_dict) is not None}.values()))
    
    # Collect all delays in a dictionary for this file
    delays_data.append({
        #'e2e_delays': e2e_delays,
        'frame_alignment_delays': frame_alignment_delays,
        'scheduling_delays': scheduling_delays,
        'ran_delays': ran_delays,
        'ran_delays_wo_frame_alignment_delay': ran_delays_wo_frame_alignment_delay,
        'ran_delays_wo_scheduling_delay': ran_delays_wo_scheduling_delay,
        'queueing_delays': queueing_delays,
        'queueing_delays_wo_scheduling_delay': queueing_delays_wo_scheduling_delay,
        'segmentation_delays': segmentation_delays,
        'segmentation_delays_wo_scheduling_delay': segmentation_delays_wo_scheduling_delay,
        'retx_delays': retx_delays,
        'segments': segments,
        'mcs': mcs,
    })

# Now you have the data from all files stored in packets_list, sched_sorted_dicts, sr_bsr_tx_sorted_lists, mcs_data, tb_data, and delays_data
# Out:
# reading from json in ./data/s49/jsons//
# RNTIs in packets: ['5fcf']
# 2024-11-12 01:39:48.119 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.128 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.131 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.134 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.205 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.207 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.222 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.223 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.239 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.240 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.275 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.280 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.282 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.283 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.298 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.300 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.352 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.355 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.623 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.626 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.666 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.667 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.668 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:48.669 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.067 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.069 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.098 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.100 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.102 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.105 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.185 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.189 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.306 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.307 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.326 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.331 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.333 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.336 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.478 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.480 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.481 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.483 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.495 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.497 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.499 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.501 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.975 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.982 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:49.998 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.000 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.001 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.004 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.230 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.231 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.393 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.395 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.411 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.416 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.418 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.420 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.621 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:50.623 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.002 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.006 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.008 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.011 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.012 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.018 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.196 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.197 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.222 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.223 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.241 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.245 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.269 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.271 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.413 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.415 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.416 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.418 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.568 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.570 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.809 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.810 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.941 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:51.944 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.085 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.088 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.090 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.092 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.113 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.115 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.117 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.120 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.247 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.251 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.382 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.384 | ERROR    | decomp:get_tx_delay:164 - Packet 39730 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.386 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.387 | ERROR    | decomp:get_tx_delay:164 - Packet 39728 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.512 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.515 | ERROR    | decomp:get_tx_delay:164 - Packet 38849 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.537 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.539 | ERROR    | decomp:get_tx_delay:164 - Packet 38686 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.565 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.567 | ERROR    | decomp:get_tx_delay:164 - Packet 38523 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.624 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.626 | ERROR    | decomp:get_tx_delay:164 - Packet 38076 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.629 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.631 | ERROR    | decomp:get_tx_delay:164 - Packet 38075 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.648 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.651 | ERROR    | decomp:get_tx_delay:164 - Packet 37951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.742 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:52.744 | ERROR    | decomp:get_tx_delay:164 - Packet 37252 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.197 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.200 | ERROR    | decomp:get_tx_delay:164 - Packet 33652 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.272 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.273 | ERROR    | decomp:get_tx_delay:164 - Packet 33089 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.275 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.276 | ERROR    | decomp:get_tx_delay:164 - Packet 33088 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.563 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.566 | ERROR    | decomp:get_tx_delay:164 - Packet 30274 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.610 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.612 | ERROR    | decomp:get_tx_delay:164 - Packet 29971 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.615 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.617 | ERROR    | decomp:get_tx_delay:164 - Packet 29970 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.723 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.726 | ERROR    | decomp:get_tx_delay:164 - Packet 29140 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.851 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.853 | ERROR    | decomp:get_tx_delay:164 - Packet 28101 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.868 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.870 | ERROR    | decomp:get_tx_delay:164 - Packet 27968 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.870 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:53.872 | ERROR    | decomp:get_tx_delay:164 - Packet 27967 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.099 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.101 | ERROR    | decomp:get_tx_delay:164 - Packet 25965 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.102 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.104 | ERROR    | decomp:get_tx_delay:164 - Packet 25964 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.127 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.130 | ERROR    | decomp:get_tx_delay:164 - Packet 25816 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.137 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.139 | ERROR    | decomp:get_tx_delay:164 - Packet 25796 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.640 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.642 | ERROR    | decomp:get_tx_delay:164 - Packet 21160 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.660 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.662 | ERROR    | decomp:get_tx_delay:164 - Packet 21004 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.666 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.668 | ERROR    | decomp:get_tx_delay:164 - Packet 21003 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.886 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:54.888 | ERROR    | decomp:get_tx_delay:164 - Packet 19143 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.094 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.098 | ERROR    | decomp:get_tx_delay:164 - Packet 17555 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.116 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.118 | ERROR    | decomp:get_tx_delay:164 - Packet 17388 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.119 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.122 | ERROR    | decomp:get_tx_delay:164 - Packet 17386 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.342 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.345 | ERROR    | decomp:get_tx_delay:164 - Packet 15574 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.805 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.807 | ERROR    | decomp:get_tx_delay:164 - Packet 11956 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.808 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.810 | ERROR    | decomp:get_tx_delay:164 - Packet 11955 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.812 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:55.816 | ERROR    | decomp:get_tx_delay:164 - Packet 11953 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.046 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.048 | ERROR    | decomp:get_tx_delay:164 - Packet 10177 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.078 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.081 | ERROR    | decomp:get_tx_delay:164 - Packet 9910 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.106 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.108 | ERROR    | decomp:get_tx_delay:164 - Packet 9747 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.132 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.134 | ERROR    | decomp:get_tx_delay:164 - Packet 9584 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.391 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.392 | ERROR    | decomp:get_tx_delay:164 - Packet 7952 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.394 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.396 | ERROR    | decomp:get_tx_delay:164 - Packet 7951 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.584 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.585 | ERROR    | decomp:get_tx_delay:164 - Packet 6469 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.774 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.776 | ERROR    | decomp:get_tx_delay:164 - Packet 4802 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.915 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:56.917 | ERROR    | decomp:get_tx_delay:164 - Packet 3484 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.044 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.045 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.046 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.047 | ERROR    | decomp:get_tx_delay:164 - Packet 2188 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.069 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.072 | ERROR    | decomp:get_tx_delay:164 - Packet 2012 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.072 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.074 | ERROR    | decomp:get_tx_delay:164 - Packet 2011 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.182 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present
# 2024-11-12 01:39:57.185 | ERROR    | decomp:get_tx_delay:164 - Packet 873 phy.in_t or phy.in_t not present
# reading from json in ./data/s40/jsons//
# RNTIs in packets: ['9afe']
# reading from json in ./data/s39/jsons//
# RNTIs in packets: ['dc46']
# 2024-11-12 01:40:23.631 | ERROR    | decomp:get_tx_delay:164 - Packet 16138 phy.in_t or phy.in_t not present
# 2024-11-12 01:40:23.633 | ERROR    | decomp:get_tx_delay:164 - Packet 16138 phy.in_t or phy.in_t not present
# 2024-11-12 01:40:23.931 | ERROR    | decomp:get_tx_delay:164 - Packet 10013 phy.in_t or phy.in_t not present
# 2024-11-12 01:40:23.933 | ERROR    | decomp:get_tx_delay:164 - Packet 10013 phy.in_t or phy.in_t not present
# 2024-11-12 01:40:24.884 | ERROR    | decomp:get_tx_delay:164 - Packet 16138 phy.in_t or phy.in_t not present
# 2024-11-12 01:40:24.885 | ERROR    | decomp:get_tx_delay:164 - Packet 16138 phy.in_t or phy.in_t not present
# 2024-11-12 01:40:25.350 | ERROR    | decomp:get_tx_delay:164 - Packet 10013 phy.in_t or phy.in_t not present
# 2024-11-12 01:40:25.352 | ERROR    | decomp:get_tx_delay:164 - Packet 10013 phy.in_t or phy.in_t not present

# %%
# Ensure the PLOTS_DIR exists
PLOTS_DIR = "./plots/combined_"+"_".join(MEAS_LABELS)+"/"
if not os.path.exists(PLOTS_DIR):
    os.makedirs(PLOTS_DIR)

# Skip constants
SKIP_FIRST = 1000
SKIP_LAST = 3000

# Initialize lists to store delay data from all DB files for each delay type
e2e_delays_per_meas = []
ran_delays_per_meas = []
scheduling_delays_per_meas = []
frame_alignment_delays_per_meas = []
ran_delays_wo_frame_alignment_delay_per_meas = []
ran_delays_wo_scheduling_delay_per_meas = []
queueing_delays_per_meas = []
queueing_delays_wo_scheduling_delay_per_meas = []
retx_delays_per_meas = []
segmentation_delays_per_meas = []
segmentation_delays_wo_scheduling_delay_per_meas = []
mcs_per_meas = []
segments_per_meas = []


# Collect delay data from each DB file
for idx, delays in enumerate(delays_data):
    #e2e_delays_per_meas.append(delays['e2e_delays'][SKIP_FIRST:-SKIP_LAST])
    ran_delays_per_meas.append(delays['ran_delays'][SKIP_FIRST:-SKIP_LAST])
    scheduling_delays_per_meas.append(delays['scheduling_delays'][SKIP_FIRST:-SKIP_LAST])
    frame_alignment_delays_per_meas.append(delays['frame_alignment_delays'][SKIP_FIRST:-SKIP_LAST])
    ran_delays_wo_frame_alignment_delay_per_meas.append(delays['ran_delays_wo_frame_alignment_delay'][SKIP_FIRST:-SKIP_LAST])
    ran_delays_wo_scheduling_delay_per_meas.append(delays['ran_delays_wo_scheduling_delay'][SKIP_FIRST:-SKIP_LAST])
    queueing_delays_per_meas.append(delays['queueing_delays'][SKIP_FIRST:-SKIP_LAST])
    queueing_delays_wo_scheduling_delay_per_meas.append(delays['queueing_delays_wo_scheduling_delay'][SKIP_FIRST:-SKIP_LAST])
    retx_delays_per_meas.append(delays['retx_delays'][SKIP_FIRST:-SKIP_LAST])
    segmentation_delays_per_meas.append(delays['segmentation_delays'][SKIP_FIRST:-SKIP_LAST])
    segmentation_delays_wo_scheduling_delay_per_meas.append(delays['segmentation_delays_wo_scheduling_delay'][SKIP_FIRST:-SKIP_LAST])
    mcs_per_meas.append(delays['mcs'][SKIP_FIRST:-SKIP_LAST])
    segments_per_meas.append(delays['segments'][SKIP_FIRST:-SKIP_LAST])

# Plot RAN Delays for all measurement files on the same axis
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(ran_delays_per_meas, ax, delay_type_label='RAN Delays', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}ran_delays_combined_ccdf_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# Plot Scheduling Delays for all measurement files on the same axis
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(scheduling_delays_per_meas, ax, delay_type_label='Scheduling Delays', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}scheduling_delays_combined_ccdf_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# Plot Frame Alignment Delays for all measurement files on the same axis
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(frame_alignment_delays_per_meas, ax, delay_type_label='Frame Alignment Delays', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}frame_alignment_delays_combined_ccdf_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# Plot RAN Delays w/o Scheduling for all measurement files on the same axis
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(ran_delays_wo_scheduling_delay_per_meas, ax, delay_type_label='RAN Delays w/o Scheduling', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}ran_delays_wo_scheduling_delay_combined_ccdf_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# Plot Queueing Delays for all measurement files on the same axis
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(queueing_delays_per_meas, ax, delay_type_label='Queueing Delays', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}queueing_delays_combined_ccdf_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# Plot Retransmission Delays for all measurement files on the same axis
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(retx_delays_per_meas, ax, delay_type_label='Retransmission Delays', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}retx_delays_combined_ccdf_plot.png", dpi=300, bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(ran_delays_wo_scheduling_delay_per_meas, ax, delay_type_label='RAN Delays w/o FA Delay', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}ran_delays_wo_frame_alignment_delay_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(queueing_delays_wo_scheduling_delay_per_meas, ax, delay_type_label='Queueing Delays w/o Scheduling Delay', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}queueing_delays_wo_scheduling_delay_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_ccdf_per_delay_type(segmentation_delays_wo_scheduling_delay_per_meas, ax, delay_type_label='Segmentation Delays w/o Scheduling Delay', labels=LABELS)
plt.savefig(f"{PLOTS_DIR}segmentation_delays_wo_scheduling_delay_ccdf_plot.png", dpi=300, bbox_inches='tight')  # You can change the file format (e.g., .pdf)
plt.show()

# Plot Segments Histograms
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_histograms(segments_per_meas, ax, delay_type_label='No. of Segments', labels=LABELS, y_log=True, outlier=None)
plt.savefig(f"{PLOTS_DIR}segments_hist_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# Plot MCS Histograms
fig, ax = plt.subplots(figsize=(8, 5))
plot_multiple_histograms(mcs_per_meas, ax, delay_type_label='MCS Index', labels=LABELS, y_log=False, outlier=None)
plt.savefig(f"{PLOTS_DIR}mcs_hist_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Index range and skip constants
index_range = slice(2500, 2700)
SKIP_FIRST = 1000
SKIP_LAST = 100

# Create a figure and axes for frame alignment, scheduling, and RAN delays
fig, ax = plt.subplots(figsize=(12, 5))

# Plot delays for all DB files on the same axis
for idx, delays in enumerate(delays_data):
    # Extract delays for the current DB_FILE
    frame_alignment_delays = delays['frame_alignment_delays']
    scheduling_delays = delays['scheduling_delays']
    ran_delays = delays['ran_delays']
    
    # Plotting each data set with different markers and labels for each DB file
    ax.plot(frame_alignment_delays[index_range], marker='o', label=f'{LABELS[idx]}: Frame Alignment Delay')
    ax.plot(scheduling_delays[index_range], marker='o', label=f'{LABELS[idx]}: Scheduling Delay')
    ax.plot(ran_delays[index_range], marker='o', label=f'{LABELS[idx]}: RAN Delay')

# Adding labels and title
ax.set_xlabel('Index')
ax.set_ylabel('Delay [ms]')
ax.set_title('Frame Alignment, Scheduling, and RAN Delays for Multiple DB Files')

# Adding grid
ax.grid(True)

# Adding legend
ax.legend()

# Save the plot
plt.savefig(f"{PLOTS_DIR}ran_delay_timeseries_combined.png", dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# Create a figure and axes for RAN delay without frame alignment delay and scheduling delay
fig, ax = plt.subplots(figsize=(12, 5))

# Plot RAN delay without frame alignment and scheduling delays for all DB files on the same axis
for idx, delays in enumerate(delays_data):
    # Extract delays for the current DB_FILE
    frame_alignment_delays = delays['frame_alignment_delays']
    scheduling_delays = delays['scheduling_delays']
    ran_delays = delays['ran_delays']

    # Plotting each data set with different markers and labels for each DB file
    ax.plot(ran_delays[index_range] - frame_alignment_delays[index_range], marker='o', label=f'{LABELS[idx]}: RAN Delay w/o Frame-Alignment Delay')
    ax.plot(ran_delays[index_range] - scheduling_delays[index_range], marker='o', label=f'{LABELS[idx]}: RAN Delay w/o Scheduling Delay')

# Adding labels and title
ax.set_xlabel('Index')
ax.set_ylabel('Delay [ms]')
ax.set_title('RAN Delays without Frame Alignment and Scheduling Delays for Multiple DB Files')

# Adding grid
ax.grid(True)

# Adding legend
ax.legend()

# Save the plot
plt.savefig(f"{PLOTS_DIR}ran_delay_wo_scheduling_timeseries_combined.png", dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
